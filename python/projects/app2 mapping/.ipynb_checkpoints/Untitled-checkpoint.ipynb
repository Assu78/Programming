# %%
import pandas

# %%
file = pandas.read_csv("terveys.csv", sep(","))
file
# Out:
#    id;sukupuoli;pituus;paino;kolesteroli;verenpaineluokka;liikunta;ika
# 0            1;Mies;178;102;6.7;korkea;ei lainkaan;57
# 1      2;Nainen;165;60;5.2;normaali;saannollisesti;37
# 2           3;Nainen;158;87;6.3;korkea;ei lainkaan;48
# 3            4;Mies;180;70;3.9;normaali;paivittain;46
# 4        5;Mies;187;90;5.4;normaali;saannollisesti;41
# 5         6;Nainen;167;57;4.5;alhainen;ei lainkaan;30
# 6            7;Mies;173;76;4.9;normaali;paivittain;32
# 7           8;Nainen;154;46;5;alhainen;ei lainkaan;59
# 8          9;Mies;190;102;5.8;normaali;ei lainkaan;63
# 9           10;Mies;185;82;4.3;normaali;paivittain;26
# 10        11;Nainen;175;60;4.7;normaali;paivittain;35
# 11          12;Mies;180;110;8.8;korkea;ei lainkaan;36
# 12           13;Mies;168;80;5.9;korkea;ei lainkaan;28
# 13       14;Nainen;167;64;5.3;alhainen;ei lainkaan;39
# 14          15;Mies;180;68;3.8;alhainen;paivittain;23
# 15    16;Nainen;172;56;3.3;alhainen;saannollisesti;22
# ...
