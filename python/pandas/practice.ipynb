# %%
import pandas
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Geopy.ipynb',
#  'practice.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Test.ipynb']

# %%
df = pandas.read_json("supermarkets.json")
df1 = df.set_index("Address")
df1
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
df1.loc["735 Dolores St": "1056 Sanchez St", "Country": "Name"]
# Out:
#                 Country  Employees  ID         Name
# Address
# 735 Dolores St      USA         15   2  Bready Shop
# 332 Hill St         USA         25   3  Super River
# 3995 23rd St        USA         10   4   Ben's Shop
# 1056 Sanchez St     USA         12   5      Sanchez

# %%
df1.iloc[1:4, 0:4]
# Out:
#                          City Country  Employees  ID
# Address
# 735 Dolores St  San Francisco     USA         15   2
# 332 Hill St     San Francisco     USA         25   3
# 3995 23rd St    San Francisco     USA         10   4

# %%
df1.ix[2,4]
# Out:
# 'Super River'

# %%
df1[Continen]
# Out:
#                 Country  Employees  ID         Name             State
# Address
# 3666 21st St        USA          8   1      Madeira          CA 94114
# 735 Dolores St      USA         15   2  Bready Shop          CA 94119
# 332 Hill St         USA         25   3  Super River  California 94114
# 3995 23rd St        USA         10   4   Ben's Shop          CA 94114
# 1056 Sanchez St     USA         12   5      Sanchez        California
# 551 Alvarado St     USA         20   6   Richvalley          CA 94114

# %%
df1["Continent"] = df1["Country"] + "," + ["North America"]
df1
# Out:
#                           City Country  Employees  ID         Name  \
# Address
# 3666 21st St     San Francisco     USA          8   1      Madeira
# 735 Dolores St   San Francisco     USA         15   2  Bready Shop
# 332 Hill St      San Francisco     USA         25   3  Super River
# 3995 23rd St     San Francisco     USA         10   4   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#                             State          Continent
# Address
# 3666 21st St             CA 94114  USA,North America
# 735 Dolores St           CA 94119  USA,North America
# 332 Hill St      California 94114  USA,North America
# 3995 23rd St             CA 94114  USA,North America
# 1056 Sanchez St        California  USA,North America
# 551 Alvarado St          CA 94114  USA,North America

# %%
df_t = df1.T
df_t
# Out:
# Address         3666 21st St     735 Dolores St        332 Hill St  \
# City           San Francisco      San Francisco      San Francisco
# Country                  USA                USA                USA
# Employees                  8                 15                 25
# ID                         1                  2                  3
# Name                 Madeira        Bready Shop        Super River
# State               CA 94114           CA 94119   California 94114
# Continent  USA,North America  USA,North America  USA,North America
#
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco      San Francisco
# Country                  USA                USA                USA
# Employees                 10                 12                 20
# ID                         4                  5                  6
# Name              Ben's Shop            Sanchez         Richvalley
# ...

# %%
df_t["My Address"]  = ["My City", "My Country", 10, 7, "My Name", "My State", "My Continent"]
df1 = df_t.T

# %%
df1
# Out:
#                           City     Country Employees ID         Name  \
# Address
# 3666 21st St     San Francisco         USA         8  1      Madeira
# 735 Dolores St   San Francisco         USA        15  2  Bready Shop
# 332 Hill St      San Francisco         USA        25  3  Super River
# 3995 23rd St     San Francisco         USA        10  4   Ben's Shop
# 1056 Sanchez St  San Francisco         USA        12  5      Sanchez
# 551 Alvarado St  San Francisco         USA        20  6   Richvalley
# My Address             My City  My Country        10  7      My Name
#
#                             State          Continent
# Address
# 3666 21st St             CA 94114  USA,North America
# 735 Dolores St           CA 94119  USA,North America
# 332 Hill St      California 94114  USA,North America
# 3995 23rd St             CA 94114  USA,North America
# 1056 Sanchez St        California  USA,North America
# 551 Alvarado St          CA 94114  USA,North America
# ...

# %%
from geopy.geocoders import Nominatim

# %%
nom = Nominatim()

# %%
df2 = pandas.read_csv("supermarkets.csv")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2["Address"] = df2["Address"] + "," + df2["City"] + "," + df2["State"] + "," + df2["Country"]
df2
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 1   2  735 Dolores St,San Francisco,CA 94119,USA,San ...  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA...  San Francisco
# 3   4  3995 23rd St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 4   5  1056 Sanchez St,San Francisco,California,USA,S...  San Francisco
# 5   6  551 Alvarado St,San Francisco,CA 94114,USA,San...  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df2["Coordinates"] = df2["Address"].apply(nom.geocode) 
df2.Coordinates[0].latitude
# Out:
# 37.7570511

# %%
df2["Latitude"] = df["Coordinates"].apply(lambda x : x.)
